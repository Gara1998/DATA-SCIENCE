# %% [markdown]
# # Filtrar y ordenar

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Ej 2. Estos son los datos dados en un diccionario.

# %%
# Crea un ejemplo de Dataframe sobre fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %% [markdown]
# ### Ej 3. Crea un Dataframe y asígnalo a una variable llamada army.

# %%
army=pd.DataFrame(raw_data)
army.head()
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 1  Nighthawks     1st      52       42   957         5          2        0
# 2  Nighthawks     2nd      25        2  1099        62          3        1
# 3  Nighthawks     2nd     616        2  1400        26          3        1
# 4    Dragoons     1st      43        4  1592        73          2        0
#
#    deserters      origin
# 0          4     Arizona
# 1         24  California
# 2         31       Texas
# 3          2     Florida
# 4          3       Maine

# %% [markdown]
# Primero que todo obtenemos la informacion basica de nuestro Data Frame:

# %%
army.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   regiment   12 non-null     object
#  1   company    12 non-null     object
#  2   deaths     12 non-null     int64
#  3   battles    12 non-null     int64
#  4   size       12 non-null     int64
#  5   veterans   12 non-null     int64
#  6   readiness  12 non-null     int64
#  7   armored    12 non-null     int64
#  8   deserters  12 non-null     int64
#  9   origin     12 non-null     object
# dtypes: int64(7), object(3)
# memory usage: 1.1+ KB

# %%
army.describe(include='all')
# Out:
#           regiment company      deaths    battles         size    veterans  \
# count           12      12   12.000000  12.000000    12.000000   12.000000
# unique           3       2         NaN        NaN          NaN         NaN
# top     Nighthawks     1st         NaN        NaN          NaN         NaN
# freq             4       6         NaN        NaN          NaN         NaN
# mean           NaN     NaN  190.416667   8.416667  1127.916667  174.333333
# std            NaN     NaN  227.027615  10.849871   240.241719  280.254214
# min            NaN     NaN   25.000000   2.000000   849.000000    1.000000
# 25%            NaN     NaN   41.500000   3.750000   983.500000   34.250000
# 50%            NaN     NaN   62.000000   6.000000  1025.500000   55.000000
# 75%            NaN     NaN  306.250000   8.000000  1174.250000  141.000000
# max            NaN     NaN  616.000000  42.000000  1592.000000  949.000000
#
#         readiness    armored  deserters   origin
# ...

# %% [markdown]
# ### Ej 4. Establece la variable 'origin' como el índice del Dataframe.

# %%
army=army.set_index('origin')

# %%
army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %% [markdown]
# ### Ej 5. Imprime solo la columna veterans.

# %%
army.veterans
# Out:
# origin
# Arizona         1
# California      5
# Texas          62
# Florida        26
# Maine          73
# Iowa           37
# Alaska        949
# Washington     48
# Oregon         48
# Wyoming       435
# Louisana       63
# Georgia       345
# Name: veterans, dtype: int64

# %%
army.loc[:,'veterans']
# Out:
# origin
# Arizona         1
# California      5
# Texas          62
# Florida        26
# Maine          73
# Iowa           37
# Alaska        949
# Washington     48
# Oregon         48
# Wyoming       435
# Louisana       63
# Georgia       345
# Name: veterans, dtype: int64

# %% [markdown]
# ### Ej 6. Imprime las columnas 'veterans' y 'deaths'.

# %%
army.loc[:,['veterans','deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35

# %%
army[['veterans','deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35

# %% [markdown]
# ### Ej 7. Imprime el nombre de todas las columnas.

# %%
army.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters'],
#       dtype='object')

# %%
army.keys()
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters'],
#       dtype='object')

# %% [markdown]
# ### Ej 8. Selecciona las columnas 'deaths', 'size' y 'deserters' de Maine y Alaska.

# %%
army[(army.index=='Maine') | (army.index=='Alaska') ].loc[:,['deaths','size','deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %%
army.loc[['Maine','Alaska'],['deaths','size','deserters']] #MEJOR
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %% [markdown]
# ### Ej 9. Selecciona las filas de la 3 a la 7 y las columnas de la 3 a la 6.

# %%
army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
#CUIDADO PIDE ESTO
army.iloc[2:7,2:6]
# Out:
#          deaths  battles  size  veterans
# origin
# Texas        25        2  1099        62
# Florida     616        2  1400        26
# Maine        43        4  1592        73
# Iowa        234        7  1006        37
# Alaska      523        8   987       949

# %%
army.iloc[3:8,3:7] #no pide esto
# Out:
#             battles  size  veterans  readiness
# origin
# Florida           2  1400        26          3
# Maine             4  1592        73          2
# Iowa              7  1006        37          1
# Alaska            8   987       949          2
# Washington        3   849        48          3

# %% [markdown]
# ### Ej 10. Selecciona todas las filas después de la cuarta y todas las columnas.

# %%
army.iloc[4:,:]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Maine       Dragoons     1st      43        4  1592        73          2
# Iowa        Dragoons     1st     234        7  1006        37          1
# Alaska      Dragoons     2nd     523        8   987       949          2
# Washington  Dragoons     2nd      62        3   849        48          3
# Oregon        Scouts     1st      62        4   973        48          2
# Wyoming       Scouts     1st      73        7  1005       435          1
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ### Ej 11. Selecciona todas las filas antes de la cuarta y todas las columnas.

# %%
army.iloc[:3,:] #La cuarta fila no esta incluida
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31

# %% [markdown]
# ### Ej 12. Selecciona de la tercera a la séptima columna.

# %%
army.iloc[:,2:7]
# Out:
#             battles  size  veterans  readiness  armored
# origin
# Arizona           5  1045         1          1        1
# California       42   957         5          2        0
# Texas             2  1099        62          3        1
# Florida           2  1400        26          3        1
# Maine             4  1592        73          2        0
# Iowa              7  1006        37          1        1
# Alaska            8   987       949          2        0
# Washington        3   849        48          3        1
# Oregon            4   973        48          2        0
# Wyoming           7  1005       435          1        0
# Louisana          8  1099        63          2        1
# Georgia           9  1523       345          3        1

# %% [markdown]
# ### Ej 13. Selecciona las filas donde deaths es mayor que 50.

# %%
army[army.deaths>50]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# ...

# %%
army.loc[army.deaths>50]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# ...

# %% [markdown]
# ### Ej 14. Selecciona las filas donde la variable deaths es mayor que 500 o menor que 50.

# %%
army[(army.deaths>500) | (army.deaths<50)]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona   Nighthawks     1st     523        5  1045         1          1
# Texas     Nighthawks     2nd      25        2  1099        62          3
# Florida   Nighthawks     2nd     616        2  1400        26          3
# Maine       Dragoons     1st      43        4  1592        73          2
# Alaska      Dragoons     2nd     523        8   987       949          2
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#           armored  deserters
# origin
# Arizona         1          4
# Texas           1         31
# Florida         1          2
# Maine           0          3
# Alaska          0         24
# Louisana        1          2
# Georgia         1          3

# %% [markdown]
# ### Ej 15. Selecciona todos los regimientos que no se llamen "Dragoons".

# %%
army[army.regiment!='Dragoons']
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# ...

# %% [markdown]
# ### Ej 16. Selecciona todas las filas llamadas Texas o Arizona.

# %%
army.loc[['Texas','Arizona']]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd      25        2  1099        62          3
# Arizona  Nighthawks     1st     523        5  1045         1          1
#
#          armored  deserters
# origin
# Texas          1         31
# Arizona        1          4

# %%
army[(army.index=='Texas') | (army.index=='Arizona')]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona  Nighthawks     1st     523        5  1045         1          1
# Texas    Nighthawks     2nd      25        2  1099        62          3
#
#          armored  deserters
# origin
# Arizona        1          4
# Texas          1         31

# %% [markdown]
# ### Ej 17. Selecciona la tercera celda de la fila llamada Arizona.

# %%
army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
army.loc['Arizona'].iloc[2] #FORMA MAS CORRECTA
# Out:
# 523

# %%
army[army.index=='Arizona'].iloc[:,2]
# Out:
# origin
# Arizona    523
# Name: deaths, dtype: int64

# %% [markdown]
# ### Ej 18. Selecciona la tercera celda de la columna llamada deaths.

# %%
army.loc[:,'deaths'].iloc[2] #EMPIEZA POR CERO LA TERCERA COLUMNA ES LA 2
# Out:
# 25

# %%
army['deaths'].iloc[2]
# Out:
# 25
