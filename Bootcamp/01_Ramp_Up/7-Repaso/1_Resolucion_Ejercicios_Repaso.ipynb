# %% [markdown]
# ### Ejercicio 1
# En este ejercicio se va a crear una lista con los siguientes elementos. Primero, crearemos las variables que luego añadiremos a la lista. Las variables son las siguientes:
#
# 1. Crea una variable llamada `edad` de tipo Integer que represente tu edad en años.
# 2. Crea una variable llamada `poblacion` de tipo String , con tu población de nacimiento.
# 3. Crea una variable llamada `altura` con el valor de tu altura en metros de tipo float.
# 4. Crea una variable llamada `s_operativo` de tipo Boolean True si usas Windows y False si usas otro.
# 5. Crea una variable llamada `nada` de tipo None cuyo valor sea None.
# 6. Crea una variable llamada `lista_vacaciones` de tipo List que contenga 5 destinos de viaje a los que te gustaría ir. Cada elemento ha de ser de tipo String.
# 7. Crea una variable llamada `tupla_isla` de tipo Tuple con tres objetos que te llevarías a una isla desierta.
# 8. Crea una variable llamada `dict_pc` con dos keys y dos values. Una key es `marca`, teniendo como value la marca de tu pc de tipo String. Otra key es la `ram`, cuyo valor es es un entero del número de gigas de la ram de tu ordenador
# 9. Añade todos estos elementos en una lista llamada `lista_examen` en el orden de aparición.
# 10. Guarda en la variable `lon_lista_examen` la longitud de `lista_examen`.

# %%
# 1. Crea una variable llamada `edad` de tipo Integer que represente tu edad en años. 
edad = 28
# 2. Crea una variable llamada `poblacion` de tipo String , con tu población de nacimiento. 
poblacion = 'Bilbao'
# 3. Crea una variable llamada `altura` con el valor de tu altura en metros de tipo float.
altura = 1.8
# 4. Crea una variable llamada `s_operativo` de tipo Boolean True si usas Windows y False si usas otro.
s_operativo = True
# 5. Crea una variable llamada `nada` de tipo None cuyo valor sea None.
nada = None
# 6. Crea una variable llamada `lista_vacaciones` de tipo List que contenga 5 destinos de viaje a los que te gustaría ir. Cada elemento ha de ser de tipo String.
lista_vacaciones = ['La Selva Negra de Alemania', 'Costa Marfitana', 'Alpes', 'Las tierras altas de Escocia', 'Riaño']
# 7. Crea una variable llamada `tupla_isla` de tipo Tuple con tres objetos que te llevarías a una isla desierta.
tupla_isla = ('Equipo de buceo', 'Bañador', 'Parrilla')
# 8. Crea una variable llamada `dict_pc` con dos keys y dos values. Una key es `marca`, teniendo como value la marca de tu pc de tipo String. Otra key es la `ram`, cuyo valor es es un entero del número de gigas de la ram de tu ordenador
dict_pc = {'marca': 'HP', 'ram': 16}
# 9. Añade todos estos elementos en una lista llamada `lista_examen` en el orden de aparición.
lista_examen = [edad, poblacion, altura, s_operativo, nada, lista_vacaciones, tupla_isla, dict_pc]
# 10. Guarda en la variable `lon_lista_examen` la longitud de `lista_examen`.
lon_lista_examen = len(lista_examen)

# %% [markdown]
# ### Ejercicio 2
#
# Para resolver este ejercicio necesitarás la lista del ejercicio anterior (`lista_examen`). Se recomienda leer cada punto hasta el final antes de resolver el ejercicio.
#
# Se repite para que quede aún más claro: **SOLO USAR LA VARIABLE** `lista_examen`. Usar otra variable se calificará como error.
#
# 1. Guardar en las variables, sin uso de funciones (puedes usar print) ni bucles:
#     - `res21` El tercer destino de vacaciones
#     - `res22` El penúltimo objeto que te llevarías a una isla para todo tipo de longitudes de listados.
#     - `res23` Los 3 primeros caracteres de la población de nacimiento.
#     - `res24` Una lista de los valores del diccionario de tu pc.
#     - `res25` Guardar dentro del diccionario dentro de `lista_examen` una nueva clave llamada `s_operativo` con una lista de 3 booleanos, True si es Windows, de tus últimos 3 pcs.
#
# <br></br>
#
# 2. Mostrar por pantalla, con uso de un bucle `for`:
#     - Las posiciones y elementos de `lista_examen` de las posiciones impares.
#     - Todos los elementos de `lista_examen` al revés.
#     - Todos aquellos elementos que sean colecciones ordenadas de `lista_examen`, si no lo son, imprimir el tipo.
#
# <br></br>
#
# 3. Con uso del bucle `while`, borra los destinos por la cola hasta que tengas 3 destinos, y guarda esos destinos borrados en una nueva lista `destinos_borrados`.

# %%
# 1. Guardar en las variables, sin uso de funciones (puedes usar print) ni bucles: 
#     - res21: El tercer destino de vacaciones
res21 = lista_examen[5][2]; print(res21)
#     - res22: El penúltimo objeto que te llevarías a una isla para todo tipo de longitudes de listados.
res22 = lista_examen[-2][-2]; print(res22)
#     - res23: Los 3 primeros caracteres de la población de nacimiento.
res23 = lista_examen[1][0:3]; print(res23)
#     - res24: Una lista de los valores del diccionario de tu pc.
res24 = list(lista_examen[7].values()); print(res24)
#     - res25: Guardar dentro del diccionario dentro de `lista_examen` una nueva clave llamada `s_operativo` con una lista de 3 booleanos, True si es Windows, de tus últimos 3 pcs.
lista_examen[7]['s_operativo'] = [True, True, True]; print(lista_examen[7])

# %%
# 2. Mostrar por pantalla, con uso de un bucle `for`:
#     - Las posiciones y elementos de `lista_examen` de las posiciones impares.
for i in range(1, lon_lista_examen, 2):
    print(i, lista_examen[i])

print('---------------------------------------------------------------------------------------------------')
#     - Todos los elementos de `lista_examen` al revés.
for i in range((lon_lista_examen-1),-1,-1):
    print(lista_examen[i])

print('----------------')

for i in range(-1,-(lon_lista_examen+1),-1):
    print(lista_examen[i])

print('----------------')

for i in reversed(lista_examen):
    print(i)

print('---------------------------------------------------------------------------------------------------')
#     - Todos aquellos elementos que sean colecciones ordenadas de `lista_examen`, si no lo son, imprimir el tipo.
for elemento in lista_examen:
    tipo_elemen = type(elemento)
    if tipo_elemen not in [list, tuple]:
        print(tipo_elemen)

# %%
# 3. Con uso del bucle `while`, borra los destinos por la cola hasta que tengas 3 destinos, 
# y guarda esos destinos borrados en una nueva lista `destinos_borrados`.
lon_destinos = len(lista_examen[5])
destinos_borrados = []

while lon_destinos>3:
    destinos_borrados.append(lista_examen[5].pop(-1))
    lon_destinos-=1
print(destinos_borrados)

# %% [markdown]
# ### Ejercicio 3
#
# #### Crear un programa que calcule la cuota de una hipoteca
#
# Las cuotas hipotecarias se calculan utilizando la fórmula del interés francés.
#
# La fórmula del interés frances es la siguiente:
# \begin{align*}
# C=V \frac{(1+i)^n i}{(1+i)^n -1}
# \end{align*}
#
#
#     C = cuota a pagar (mensual)
#     V = volumen del préstamo hipotecario
#     i = tipo de interés del período (mensual)
#     n = número de cuotas (mensuales)
#
# 1. Crea un programa que solicite al usuario los datos de su hipoteca mediante input() los datos (volumen, interés **anual**, y plazo en **años**) y le devuelva la cuota **mensual** a pagar. No es necesario encapsularlo en funciones.
#
# 2. Crea una función `calcular_hip` que realiza el cálculo y cuyos argumentos de entrada sean `volumen`, `interes_anual` y `años`, devolviendo la couta mensual(float). El argumento de `años` deberá de tener un valor por defecto de 30.
# 3. Calcula la cuota y guárdala en la variable `res_cuota` si la cantidad de la hipoteca son 350000 euros, el interés anual es del 5% y la quiere pagar en 20 años a partir de la función `calcular_hip`.
# 4. Crea una función `gasto_vivienda`, con dos argumentos de entrada `ingreso` y `lista_hip`. Esta lista tendrá los 3 valores de los argumentos de entrada de `calcular_hip`, siendo esta una función que deberá ser utilizada dentro de `gasto_vivienda`. Tiene que devolver el valor del porcentaje de gasto en la hipoteca respecto a los ingresos. (Entre 0 y 1, es decir 0.5 si es del 50%)
# 5. Calcula el porcentaje de gasto en la hipoteca si el ingreso es de 1700 euros y guárdalo en la variable `res_porcentaje`.
# 6. Documenta ambas funciones con el estilo de Google.

# %%
# 1. Crea un programa que solicite al usuario los datos de su hipoteca mediante input() los datos 
# (volumen, interés anual, y plazo en años) y le devuelva la cuota mensual a pagar. No es necesario 
# encapsularlo en funciones.

def info_hipo():
    volumen=float(input('Introduce el volumen del prestamo hipotecario, '))
    int_anual=float(input('Introduce el interés anual, '))/100/12
    pl_anios=float(input('Introduce el plazo en años, '))*12

    num_cuota = ((1+int_anual)**pl_anios)*int_anual
    den_cuota = (((1+int_anual)**pl_anios)-1)

    cuota = volumen*(num_cuota/den_cuota)

    return cuota


# 2. Crea una función `calcular_hip` que realiza el cálculo y cuyos argumentos de entrada sean `volumen`, 
# `interes_anual` y `años`, devolviendo la couta mensual(float). El argumento de `años` deberá de tener 
# un valor por defecto de 30.

def calcular_hip(volumen, interes_anual, anios=30):

    meses = anios*12
    interes_per = interes_anual/100/12

    num_cuota = ((1+interes_per)**meses)*interes_per
    den_cuota = (((1+interes_per)**meses)-1)

    cuota = volumen*(num_cuota/den_cuota)

    return cuota


# 3. Calcula la cuota y guárdala en la variable `res_cuota` si la cantidad de la hipoteca son 350000 euros, 
# el interés anual es del 5% y la quiere pagar en 20 años a partir de la función `calcular_hip`.

res_cuota = calcular_hip(350000, 5, 20); print(res_cuota)


# 4. Crea una función `gasto_vivienda`, con dos argumentos de entrada `ingreso` y `lista_hip`. Esta lista 
# tendrá los 3 valores de los argumentos de entrada de `calcular_hip`, siendo esta una función que deberá 
# ser utilizada dentro de `gasto_vivienda`. Tiene que devolver el valor del porcentaje de gasto en la 
# hipoteca respecto a los ingresos. (Entre 0 y 1, es decir 0.5 si es del 50%)

def gasto_vivienda(ingreso, lista_hip):

    cuota = calcular_hip(lista_hip[0], lista_hip[1], lista_hip[2])

    return cuota/ingreso


# 5. Calcula el porcentaje de gasto en la hipoteca si el ingreso es de 1700 euros y guárdalo en la variable 
# `res_porcentaje`.
ing = 1700
list_inf = [350000, 5, 20]

res_porcentaje = gasto_vivienda(ing, list_inf); print(res_porcentaje)


# 6. Documenta ambas funciones con el estilo de Google.

# %% [markdown]
# ### Ejercicio 4
#
# 1. Crea una clase `Cliente` que tenga 1 atributo general `mamífero`(bool True) y 6 atributos en el constructor: `ojos`(int default 2), `altura`(float), `edad`(int), `ahorros`(float), `target`(bool default True) y `nombre`(str). Además, debe contar con dos métodos:
#
# - `cumplir_edad()`: al llamar a este método se debe sumar 1 al atributo edad del cliente y que retorne "Felices x años!" con la edad actualizada. Si cumple 80, su altura pasará a ser el 90% de su altura original.
# - `comprar()` que recibe el argumento de `volumen_gasto`(list): este método debe actualizar el atributo de ahorros, restándole el volumen del gasto total, retornando esos ahorros actualizados. Si el cliente tiene 0 ahorros o menos, deberá de cambiar el atributo `target` a False.
#
# 2. (a partir de la variable **`lista_examen`**) Crea un cliente instanciandolo en el objeto `cliente_1` llamado "Manuel" que tiene el doble de tu de edad y mide 10 centímetros menos que tu altura. Tiene unos ahorros de 3000 euros, y al ser un cliente con capacidad de gasto en nuestro negocio, queremos fidelizarlo en nuestra campaña, el valor `target` será True el resto de atributos puedes elegir un valor.
#
# 3. (a partir de la variable **`lista_examen`**) Crea un cliente instanciandolo en el objeto `cliente_2` llamada "Laura" con la mitad de tu edad y la altura de Manuel. Tiene unos ahorros de 2000 euros y al ser un cliente con capacidad de gasto en nuestro negocio, queremos fidelizarlo en nuestra campaña, el valor `target` será True el resto de atributos puedes elegir un valor.
#
# 4. Haz que cumplan años tus dos clientes. Les quieres fidelizar, por lo que les mandas una oferta comercial de productos. Manuel compra 3 productos de 1000, 400 y 2000 euros mientras que Laura compra solo 1 producto de 1000. Comprueba el valor de los atributos `edad` , `ahorros` y `target` de ambos clientes.
#
# 5. Documenta la clase con el estilo de Google

# %%
# 1. Crea una clase `Cliente` que tenga 1 atributo general `mamífero`(bool True) y 6 atributos en el constructor: 
# `ojos`(int default 2), `altura`(float), `edad`(int), `ahorros`(float), `target`(bool default True) y 
# `nombre`(str). Además, debe contar con dos métodos: 

## - `cumplir_edad()`: al llamar a este método se debe sumar 1 al atributo edad del cliente y que retorne 
## "Felices x años!" con la edad actualizada. Si cumple 80, su altura pasará a ser el 90% de su altura original.
## - `comprar()` que recibe el argumento de `volumen_gasto`(list): este método debe actualizar el atributo de 
## ahorros, restándole el volumen del gasto total, retornando esos ahorros actualizados. Si el cliente tiene 0 
## ahorros o menos, deberá de cambiar el atributo `target` a False.

class Cliente:

    mamifero = True

    def __init__(self, altura, edad, ahorros, nombre, ojos = 2, target = True):
        self.ojos = ojos
        self.altura = altura
        self.edad = edad
        self.ahorros = ahorros
        self.target = target
        self.nombre = nombre

    def cumplir_edad(self):
        self.edad += 1

        if self.edad == 80:
            self.altura = 0.9*self.altura

        mensaje = 'Felices ' + str(self.edad) + ' años!'
        return mensaje

    def comprar(self, volumen_gastos):

        gastos = sum(volumen_gastos)

        self.ahorros -= gastos 
        if self.ahorros <= 0:
            self.target = False


# 2. (a partir de la variable `lista_examen`) Crea un cliente instanciandolo en el objeto `cliente_1` llamado 
# "Manuel" que tiene el doble de tu de edad y mide 10 centímetros menos que tu altura. Tiene unos ahorros de 
# 3000 euros, y al ser un cliente con capacidad de gasto en nuestro negocio, queremos fidelizarlo en nuestra 
# campaña, el valor `target` será True el resto de atributos puedes elegir un valor.

cliente1 = Cliente(altura = lista_examen[2]-0.1, edad = lista_examen[0]*2, ahorros = 3000, nombre = 'Manuel')


# 3. (a partir de la variable `lista_examen`) Crea un cliente instanciandolo en el objeto `cliente_2` llamada 
# "Laura" con la mitad de tu edad y la altura de Manuel. Tiene unos ahorros de 2000 euros y al ser un cliente 
# con capacidad de gasto en nuestro negocio, queremos fidelizarlo en nuestra campaña, el valor `target` será 
# True el resto de atributos puedes elegir un valor.

cliente2 = Cliente(altura = lista_examen[2]-0.1, edad = lista_examen[0]/2, ahorros = 2000, nombre = 'Laura')

# 4. Haz que cumplan años tus dos clientes. Les quieres fidelizar, por lo que les mandas una oferta comercial de 
# productos. Manuel compra 3 productos de 1000, 400 y 2000 euros mientras que Laura compra solo 1 producto de 
# 1000. Comprueba el valor de los atributos `edad` , `ahorros` y `target` de ambos clientes.

cliente1.cumplir_edad()
cliente2.cumplir_edad()

gastos_Manuel = [1000, 400, 2000]
gastos_Laura = [1000]

cliente1.comprar(gastos_Manuel)
cliente2.comprar(gastos_Laura)

print('Cliente Manuel: edad=' + str(cliente1.edad) + ', ahorros=' + str(cliente1.ahorros) + ', target=' + str(cliente1.target))
print('Cliente Laura: edad=' + str(cliente2.edad) + ', ahorros=' + str(cliente2.ahorros) + ', target=' + str(cliente2.target))

# 5. Documenta la clase con el estilo de Google
